# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_dwell_time, plot_transition_matrix

# %%
n_window_sz = 137
n_window_asd = 168

suptitle_fontsize = 20

fig = plt.figure(constrained_layout=True, figsize=(21, 14))
subfigs = fig.subfigures(4, 2)
(ax11, ax12, ax13) = subfigs[0,0].subplots(1, 3)
(ax14, ax15, ax16) = subfigs[0,1].subplots(1, 3)
(ax21, ax22, ax23) = subfigs[1,0].subplots(1, 3)
(ax24, ax25, ax26) = subfigs[1,1].subplots(1, 3)
(ax31, ax32, ax33) = subfigs[2,0].subplots(1, 3)
(ax34, ax35, ax36) = subfigs[2,1].subplots(1, 3)
(ax41, ax42, ax43) = subfigs[3,0].subplots(1, 3)
(ax44, ax45, ax46) = subfigs[3,1].subplots(1, 3)

subfigs[0,0].suptitle('a  FBIRN generated dFNC states (training)', color="k", fontweight="bold", fontsize=suptitle_fontsize)
subfigs[0,1].suptitle('b  FBIRN original dFNC states (training)', color="k", fontweight="bold", fontsize=suptitle_fontsize)
subfigs[1,0].suptitle('c  FBIRN generated dFNC states (test)', color="k", fontweight="bold", fontsize=suptitle_fontsize)
subfigs[1,1].suptitle('d  FBIRN original dFNC states (test)', color="k", fontweight="bold", fontsize=suptitle_fontsize)

subfigs[2,0].suptitle('e  ABIDE I generated dFNC states (training)', color="k", fontweight="bold", fontsize=suptitle_fontsize)
subfigs[2,1].suptitle('f  ABIDE I original dFNC states (training)', color="k", fontweight="bold", fontsize=suptitle_fontsize)
subfigs[3,0].suptitle('g  ABIDE I generated dFNC states (test)', color="k", fontweight="bold", fontsize=suptitle_fontsize)
subfigs[3,1].suptitle('h  ABIDE I original dFNC states (test)', color="k", fontweight="bold", fontsize=suptitle_fontsize)

data_path = '/data/users4/xli/interpolation/results/dfnc_sz/vae/hypopt/layer7/seed8'
vae_dwell_state_mean_sz = np.load(os.path.join(data_path, 'vae_dwell_state_mean_pt.npy'))
vae_dwell_state_ste_sz = np.load(os.path.join(data_path, 'vae_dwell_state_ste_pt.npy'))
vae_dwell_state_mean_sz_hc = np.load(os.path.join(data_path, 'vae_dwell_state_mean_hc.npy'))
vae_dwell_state_ste_sz_hc = np.load(os.path.join(data_path, 'vae_dwell_state_ste_hc.npy'))
vae_dwell_state_pvalue_sz_hc = np.load(os.path.join(data_path, 'vae_dwell_state_pvalue.npy'))
vae_transition_matrix_sz = np.load(os.path.join(data_path, 'vae_transition_matrix_pt.npy'))
vae_transition_matrix_sz_hc = np.load(os.path.join(data_path, 'vae_transition_matrix_hc.npy'))
vae_transition_matrix_pvalue_sz_hc = np.load(os.path.join(data_path, 'vae_transition_matrix_pvalue.npy'))

dwell_state_mean_sz = np.load(os.path.join(data_path, 'dwell_state_mean_pt.npy'))
dwell_state_ste_sz = np.load(os.path.join(data_path, 'dwell_state_ste_pt.npy'))
dwell_state_mean_sz_hc = np.load(os.path.join(data_path, 'dwell_state_mean_hc.npy'))
dwell_state_ste_sz_hc = np.load(os.path.join(data_path, 'dwell_state_ste_hc.npy'))
dwell_state_pvalue_sz_hc = np.load(os.path.join(data_path, 'dwell_state_pvalue.npy'))
transition_matrix_sz = np.load(os.path.join(data_path, 'transition_matrix_pt.npy'))
transition_matrix_sz_hc = np.load(os.path.join(data_path, 'transition_matrix_hc.npy'))
transition_matrix_pvalue_sz_hc = np.load(os.path.join(data_path, 'transition_matrix_pvalue.npy'))

vae_dwell_state_mean_sz_test = np.load(os.path.join(data_path, 'vae_dwell_state_mean_pt_test.npy'))
vae_dwell_state_ste_sz_test = np.load(os.path.join(data_path, 'vae_dwell_state_ste_pt_test.npy'))
vae_dwell_state_mean_sz_hc_test = np.load(os.path.join(data_path, 'vae_dwell_state_mean_hc_test.npy'))
vae_dwell_state_ste_sz_hc_test = np.load(os.path.join(data_path, 'vae_dwell_state_ste_hc_test.npy'))
vae_dwell_state_pvalue_sz_hc_test = np.load(os.path.join(data_path, 'vae_dwell_state_pvalue_test.npy'))
vae_transition_matrix_sz_test = np.load(os.path.join(data_path, 'vae_transition_matrix_pt_test.npy'))
vae_transition_matrix_sz_hc_test = np.load(os.path.join(data_path, 'vae_transition_matrix_hc_test.npy'))
vae_transition_matrix_pvalue_sz_hc_test = np.load(os.path.join(data_path, 'vae_transition_matrix_pvalue_test.npy'))

dwell_state_mean_sz_test = np.load(os.path.join(data_path, 'dwell_state_mean_pt_test.npy'))
dwell_state_ste_sz_test = np.load(os.path.join(data_path, 'dwell_state_ste_pt_test.npy'))
dwell_state_mean_sz_hc_test = np.load(os.path.join(data_path, 'dwell_state_mean_hc_test.npy'))
dwell_state_ste_sz_hc_test = np.load(os.path.join(data_path, 'dwell_state_ste_hc_test.npy'))
dwell_state_pvalue_sz_hc_test = np.load(os.path.join(data_path, 'dwell_state_pvalue_test.npy'))
transition_matrix_sz_test = np.load(os.path.join(data_path, 'transition_matrix_pt_test.npy'))
transition_matrix_sz_hc_test = np.load(os.path.join(data_path, 'transition_matrix_hc_test.npy'))
transition_matrix_pvalue_sz_hc_test = np.load(os.path.join(data_path, 'transition_matrix_pvalue_test.npy'))

data_path = '/data/users4/xli/interpolation/results/dfnc_asd/vae/hypopt/layer5/seed9'
vae_dwell_state_mean_asd = np.load(os.path.join(data_path, 'vae_dwell_state_mean_pt.npy'))
vae_dwell_state_ste_asd = np.load(os.path.join(data_path, 'vae_dwell_state_ste_pt.npy'))
vae_dwell_state_mean_asd_hc = np.load(os.path.join(data_path, 'vae_dwell_state_mean_hc.npy'))
vae_dwell_state_ste_asd_hc = np.load(os.path.join(data_path, 'vae_dwell_state_ste_hc.npy'))
vae_dwell_state_pvalue_asd_hc = np.load(os.path.join(data_path, 'vae_dwell_state_pvalue.npy'))
vae_transition_matrix_asd = np.load(os.path.join(data_path, 'vae_transition_matrix_pt.npy'))
vae_transition_matrix_asd_hc = np.load(os.path.join(data_path, 'vae_transition_matrix_hc.npy'))
vae_transition_matrix_pvalue_asd_hc = np.load(os.path.join(data_path, 'vae_transition_matrix_pvalue.npy'))

dwell_state_mean_asd = np.load(os.path.join(data_path, 'dwell_state_mean_pt.npy'))
dwell_state_ste_asd = np.load(os.path.join(data_path, 'dwell_state_ste_pt.npy'))
dwell_state_mean_asd_hc = np.load(os.path.join(data_path, 'dwell_state_mean_hc.npy'))
dwell_state_ste_asd_hc = np.load(os.path.join(data_path, 'dwell_state_ste_hc.npy'))
dwell_state_pvalue_asd_hc = np.load(os.path.join(data_path, 'dwell_state_pvalue.npy'))
transition_matrix_asd = np.load(os.path.join(data_path, 'transition_matrix_pt.npy'))
transition_matrix_asd_hc = np.load(os.path.join(data_path, 'transition_matrix_hc.npy'))
transition_matrix_pvalue_asd_hc = np.load(os.path.join(data_path, 'transition_matrix_pvalue.npy'))

vae_dwell_state_mean_asd_test = np.load(os.path.join(data_path, 'vae_dwell_state_mean_pt_test.npy'))
vae_dwell_state_ste_asd_test = np.load(os.path.join(data_path, 'vae_dwell_state_ste_pt_test.npy'))
vae_dwell_state_mean_asd_hc_test = np.load(os.path.join(data_path, 'vae_dwell_state_mean_hc_test.npy'))
vae_dwell_state_ste_asd_hc_test = np.load(os.path.join(data_path, 'vae_dwell_state_ste_hc_test.npy'))
vae_dwell_state_pvalue_asd_hc_test = np.load(os.path.join(data_path, 'vae_dwell_state_pvalue_test.npy'))
vae_transition_matrix_asd_test = np.load(os.path.join(data_path, 'vae_transition_matrix_pt_test.npy'))
vae_transition_matrix_asd_hc_test = np.load(os.path.join(data_path, 'vae_transition_matrix_hc_test.npy'))
vae_transition_matrix_pvalue_asd_hc_test = np.load(os.path.join(data_path, 'vae_transition_matrix_pvalue_test.npy'))

dwell_state_mean_asd_test = np.load(os.path.join(data_path, 'dwell_state_mean_pt_test.npy'))
dwell_state_ste_asd_test = np.load(os.path.join(data_path, 'dwell_state_ste_pt_test.npy'))
dwell_state_mean_asd_hc_test = np.load(os.path.join(data_path, 'dwell_state_mean_hc_test.npy'))
dwell_state_ste_asd_hc_test = np.load(os.path.join(data_path, 'dwell_state_ste_hc_test.npy'))
dwell_state_pvalue_asd_hc_test = np.load(os.path.join(data_path, 'dwell_state_pvalue_test.npy'))
transition_matrix_asd_test = np.load(os.path.join(data_path, 'transition_matrix_pt_test.npy'))
transition_matrix_asd_hc_test = np.load(os.path.join(data_path, 'transition_matrix_hc_test.npy'))
transition_matrix_pvalue_asd_hc_test = np.load(os.path.join(data_path, 'transition_matrix_pvalue_test.npy'))

plot_dwell_time(ax11, vae_dwell_state_mean_sz, vae_dwell_state_ste_sz, vae_dwell_state_mean_sz_hc, vae_dwell_state_ste_sz_hc, vae_dwell_state_pvalue_sz_hc, 'r', 'SZ', 'Dwell time')
plot_dwell_time(ax14, dwell_state_mean_sz, dwell_state_ste_sz, dwell_state_mean_sz_hc, dwell_state_ste_sz_hc, dwell_state_pvalue_sz_hc, 'r', 'SZ', 'Dwell time')
plot_dwell_time(ax21, vae_dwell_state_mean_sz_test, vae_dwell_state_ste_sz_test, vae_dwell_state_mean_sz_hc_test, vae_dwell_state_ste_sz_hc_test, vae_dwell_state_pvalue_sz_hc_test, 'r', 'SZ', 'Dwell time')
plot_dwell_time(ax24, dwell_state_mean_sz_test, dwell_state_ste_sz_test, dwell_state_mean_sz_hc_test, dwell_state_ste_sz_hc_test, dwell_state_pvalue_sz_hc_test, 'r', 'SZ', 'Dwell time')

plot_dwell_time(ax31, vae_dwell_state_mean_asd, vae_dwell_state_ste_asd, vae_dwell_state_mean_asd_hc, vae_dwell_state_ste_asd_hc, vae_dwell_state_pvalue_asd_hc, 'orange', 'ASD', 'Dwell time')
plot_dwell_time(ax34, dwell_state_mean_asd, dwell_state_ste_asd, dwell_state_mean_asd_hc, dwell_state_ste_asd_hc, dwell_state_pvalue_asd_hc, 'orange', 'ASD', 'Dwell time')
plot_dwell_time(ax41, vae_dwell_state_mean_asd_test, vae_dwell_state_ste_asd_test, vae_dwell_state_mean_asd_hc_test, vae_dwell_state_ste_asd_hc_test, vae_dwell_state_pvalue_asd_hc_test, 'orange', 'ASD', 'Dwell time')
plot_dwell_time(ax44, dwell_state_mean_asd_test, dwell_state_ste_asd_test, dwell_state_mean_asd_hc_test, dwell_state_ste_asd_hc_test, dwell_state_pvalue_asd_hc_test, 'orange', 'ASD', 'Dwell time')

plot_transition_matrix(ax12, vae_transition_matrix_sz/np.expand_dims(np.sum(vae_transition_matrix_sz,axis=1),axis=1), vae_transition_matrix_pvalue_sz_hc, 'Transition probability (SZ)')
plot_transition_matrix(ax13, vae_transition_matrix_sz_hc/np.expand_dims(np.sum(vae_transition_matrix_sz_hc,axis=1),axis=1), vae_transition_matrix_pvalue_sz_hc, 'Transition probability (CTR)')
plot_transition_matrix(ax15, transition_matrix_sz/np.expand_dims(np.sum(transition_matrix_sz,axis=1),axis=1), transition_matrix_pvalue_sz_hc, 'Transition probability (SZ)')
plot_transition_matrix(ax16, transition_matrix_sz_hc/np.expand_dims(np.sum(transition_matrix_sz_hc,axis=1),axis=1), transition_matrix_pvalue_sz_hc, 'Transition probability (CTR)')

plot_transition_matrix(ax22, vae_transition_matrix_sz_test/np.expand_dims(np.sum(vae_transition_matrix_sz_test,axis=1),axis=1), vae_transition_matrix_pvalue_sz_hc_test, 'Transition probability (SZ)')
plot_transition_matrix(ax23, vae_transition_matrix_sz_hc_test/np.expand_dims(np.sum(vae_transition_matrix_sz_hc_test,axis=1),axis=1), vae_transition_matrix_pvalue_sz_hc_test, 'Transition probability (CTR)')
plot_transition_matrix(ax25, transition_matrix_sz_test/np.expand_dims(np.sum(transition_matrix_sz_test,axis=1),axis=1), transition_matrix_pvalue_sz_hc_test, 'Transition probability (SZ)')
plot_transition_matrix(ax26, transition_matrix_sz_hc_test/np.expand_dims(np.sum(transition_matrix_sz_hc_test,axis=1),axis=1), transition_matrix_pvalue_sz_hc_test, 'Transition probability (CTR)')

plot_transition_matrix(ax32, vae_transition_matrix_asd/np.expand_dims(np.sum(vae_transition_matrix_asd,axis=1),axis=1), vae_transition_matrix_pvalue_asd_hc, 'Transition probability (ASD)')
plot_transition_matrix(ax33, vae_transition_matrix_asd_hc/np.expand_dims(np.sum(vae_transition_matrix_asd_hc,axis=1),axis=1), vae_transition_matrix_pvalue_asd_hc, 'Transition probability (CTR)')
plot_transition_matrix(ax35, transition_matrix_asd/np.expand_dims(np.sum(transition_matrix_asd,axis=1),axis=1), transition_matrix_pvalue_asd_hc, 'Transition probability (ASD)')
plot_transition_matrix(ax36, transition_matrix_asd_hc/np.expand_dims(np.sum(transition_matrix_asd_hc,axis=1),axis=1), transition_matrix_pvalue_asd_hc, 'Transition probability (CTR)')

plot_transition_matrix(ax42, vae_transition_matrix_asd_test/np.expand_dims(np.sum(vae_transition_matrix_asd_test,axis=1),axis=1), vae_transition_matrix_pvalue_asd_hc_test, 'Transition probability (ASD)')
plot_transition_matrix(ax43, vae_transition_matrix_asd_hc_test/np.expand_dims(np.sum(vae_transition_matrix_asd_hc_test,axis=1),axis=1), vae_transition_matrix_pvalue_asd_hc_test, 'Transition probability (CTR)')
plot_transition_matrix(ax45, transition_matrix_asd_test/np.expand_dims(np.sum(transition_matrix_asd_test,axis=1),axis=1), transition_matrix_pvalue_asd_hc_test, 'Transition probability (ASD)')
plot_transition_matrix(ax46, transition_matrix_asd_hc_test/np.expand_dims(np.sum(transition_matrix_asd_hc_test,axis=1),axis=1), transition_matrix_pvalue_asd_hc_test, 'Transition probability (CTR)')

plt.savefig('dynamic_metrics.pdf')
